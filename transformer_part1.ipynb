# %% [markdown]
# #pip install

# %%
# !pip install transformers
# !pip install pipline
# !pip install datasets

# %% [markdown]
# # start to ..!

# %%
from datasets import load_dataset

dataset = load_dataset("SeyedAli/Persian-Text-Sentiment")

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 55852
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 13964
#     })
# })

# %%
train=dataset['train']
train
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 55852
# })

# %%
train.column_names
# Out:
# ['text', 'label']

# %%
print(train.features)
# Out:
# {'text': Value(dtype='string', id=None), 'label': Value(dtype='int64', id=None)}

# %%
test=dataset['test']
test
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 13964
# })

# %% [markdown]
# #pandas

# %%
import pandas as pd

dataset.set_format(type='pandas')
df_train=dataset['train'][:]
df_train.head(10)
# Out:
#                                                 text  label
# 0  این هندس فری تازه به دستم رسیده  و برای کسایی ...      1
# 1        عالی بود عالی، امیدوارم کیفیت همینجور بمونه      1
# 2  من وقتی این ایرباد به لپ تاپ ایسوس  وصل میکنم ...      1
# 3  با عرض سلام ضمن عرض خسته نباشید چلوکباب کوبیده...      1
# 4  خوشمزه و داغ مخصوصا با سس چیلی که فرستاده بودن...      1
# 5  متاسفانه با وجود تاکید زیاد به خشک و برشته نبو...      0
# 6  طعم چیزکیک اوکی بود عالی نبود ولی اوکی بود اما...      0
# 7                 جوجه کباب خیلی پخته و خشک شده بود       0
# 8  سالاد فصل بسیار کیفیت بدی داشت وکاهوداخل ساندو...      0
# 9    من  تا مایع ظرفشویی سفارش دادم ولی یکی ارسال شد      0

# %%
X=df_train.drop('text',axis=1)
Y=df_train['label']

# %%
dict_dataset = df_train.to_dict(orient='records')

# %%
dataset.set_format(type="pandas")
df_test=dataset["test"][:]
df_test.head(5)

# %%
df_train.isnull().sum()

# %% [markdown]
# # transformers and model

# %%
from transformers import pipeline

classifire = pipeline("text-classification", model="persiannlp/wikibert-base-parsinlu-entailment")
# Out:
# config.json:   0%|          | 0.00/928 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/406M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/458 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/202k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
text=df_train.drop('label',axis=1)

# %%
text="عالی بود عالی، امیدوارم کیفیت همینجور بمونه"

# %%
output=classifire(text)
pd.DataFrame(output)
# Out:
#      label     score
# 0  LABEL_1  0.589709
